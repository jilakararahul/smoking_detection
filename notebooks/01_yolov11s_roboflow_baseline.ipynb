# %%
# !nvidia-smi
# Out:
# Fri Dec 19 18:27:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # Install YOLOv11

# %%
# !mkdir yolov11

# %%
# %cd /content/yolov11/
# Out:
# /content/yolov11

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/yolov11

# %% [markdown]
# ## Install YOLO11 via Ultralytics

# %%
# %pip install "ultralytics<=8.3.40" supervision roboflow
# !yolo settings sync=False
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/112.6 GB disk)

# %%
# %pwd
# Out:
# '/content/yolov11'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="eqsdxReuJg1Gjemw2Wel")
project = rf.workspace("rahuls-workspace-aob45").project("smoking-tasfx-7knuj")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to mountain-1 in yolov11:: 100%|██████████| 406/406 [00:00<00:00, 6250.87it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train \
  model=/content/yolov11s.pt \
  data={dataset.location}/data.yaml \
  epochs=50 \
  imgsz=320 \
  batch=16 \
  patience=10 \
  cache=True \
  name=yolo11s_results \
  plots=True
# Out:
# /content/yolov11
# New https://pypi.org/project/ultralytics/8.3.240 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r yolov11s_mountainresults.zip /content/yolov11/runs/detect/yolo11s_results
from google.colab import files
files.download('yolov11s_mountainresults.zip')
# Out:
#   adding: content/yolov11/runs/detect/yolo11s_results/ (stored 0%)
#   adding: content/yolov11/runs/detect/yolo11s_results/events.out.tfevents.1766168949.81570251f97d.2516.0 (deflated 91%)
#   adding: content/yolov11/runs/detect/yolo11s_results/val_batch2_labels.jpg (deflated 12%)
#   adding: content/yolov11/runs/detect/yolo11s_results/F1_curve.png (deflated 17%)
#   adding: content/yolov11/runs/detect/yolo11s_results/val_batch0_pred.jpg (deflated 11%)
#   adding: content/yolov11/runs/detect/yolo11s_results/train_batch1.jpg (deflated 5%)
#   adding: content/yolov11/runs/detect/yolo11s_results/PR_curve.png (deflated 20%)
#   adding: content/yolov11/runs/detect/yolo11s_results/results.png (deflated 7%)
#   adding: content/yolov11/runs/detect/yolo11s_results/val_batch0_labels.jpg (deflated 11%)
#   adding: content/yolov11/runs/detect/yolo11s_results/train_batch522.jpg (deflated 8%)
#   adding: content/yolov11/runs/detect/yolo11s_results/weights/ (stored 0%)
# ...
